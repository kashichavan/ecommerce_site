# %%
session={'cart':
    {   1:
        {'id':"1",
        "name":"james"
        }
    }
}


print(session.get('cart',{}))
# Out:
# {1: {'id': '1', 'name': 'james'}}

# %%
l=[1,2,3,'']
print(all(l))
# Out:
# False
